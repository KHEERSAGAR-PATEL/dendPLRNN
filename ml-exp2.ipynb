# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !rm -rf /kaggle/working/dendPLRNN
# !git clone --depth 1 https://github.com/DurstewitzLab/dendPLRNN.git /kaggle/working/dendPLRNN
# !pip install tensorboardX
# Out:
# Cloning into '/kaggle/working/dendPLRNN'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 137 (delta 27), reused 122 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (137/137), 60.51 MiB | 44.23 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.11/dist-packages (2.6.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (25.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX) (6.33.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->tensorboardX) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->tensorboardX) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->tensorboardX) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->tensorboardX) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->tensorboardX) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->tensorboardX) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->tensorboardX) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->tensorboardX) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->tensorboardX) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->tensorboardX) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->tensorboardX) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->tensorboardX) (2024.2.0)

# %%
# Ensure Python can find project modules
import sys
sys.path.insert(0, "/kaggle/working/dendPLRNN/BPTT_TF")
sys.path.insert(0, "/kaggle/working/dendPLRNN")
print("PYTHONPATH ready.")
# Out:
# PYTHONPATH ready.

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# !sed -i "/from bptt.multitasking/d" ubermain.py
# !sed -i "/from multitasking import/d" ubermain.py
# !sed -i "1s/^/from multitasking import Argument, run_settings, create_tasks_from_arguments\n/" ubermain.py
# !head -n 10 ubermain.py

# %%
# !sed -i "s/Argument('n_epochs', \[[0-9]\+\])/Argument('n_epochs', [200])/" ubermain.py
# !grep -n "n_epochs" ubermain.py

# %%
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" python Experiments/Table1/ECG/ubermain.py
# Out:
# python3: can't open file '/kaggle/working/Experiments/Table1/ECG/ubermain.py': [Errno 2] No such file or directory

# %%
# !ls -R /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1:
# BurstingNeuron	EEG	  Lorenz63_lowdata  Lorenz63_TDE  NeuralPopulation
# ECG		Lorenz63  Lorenz63_noisy    Lorenz96
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/BurstingNeuron:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/BurstingNeuron/data:
# burstingneuron_test.npy  burstingneuron_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG/data:
# ECG_test.npy  ECG_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/EEG:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/EEG/data:
# EEG_test.npy  EEG_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63/data:
# lorenz63_test.npy  lorenz63_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63_lowdata:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63_lowdata/data:
# lorenz63_lowdata_test.npy  lorenz63_lowdata_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63_noisy:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63_noisy/data:
# lorenz63_noisy_test.npy  lorenz63_noisy_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63_TDE:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz63_TDE/data:
# lorenz63_tde_test.npy  lorenz63_tde_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz96:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/Lorenz96/data:
# lorenz96_test.npy  lorenz96_train.npy
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/NeuralPopulation:
# data  ubermain.py
#
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/NeuralPopulation/data:
# NeuralPopulation_test.npy  NeuralPopulation_train.npy

# %%
# !ls /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# Out:
# data  ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF

# %%
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" \
python Experiments/Table1/ECG/ubermain.py
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 5, in <module>
#     from bptt import bptt_algorithm
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 5, in <module>
#     from bptt import models
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 7, in <module>
#     from bptt import saving
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/saving.py", line 9, in <module>
#     import main_eval
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main_eval.py", line 3, in <module>
#     from pandas.core.indexes import numeric
# ImportError: cannot import name 'numeric' from 'pandas.core.indexes' (/usr/local/lib/python3.11/dist-packages/pandas/core/indexes/__init__.py)

# %%
# !nvidia-smi
# Out:
# Tue Nov 11 14:39:32 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0             26W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF

# Replace the outdated pandas import inside main_eval.py
# !sed -i "s/from pandas.core.indexes import numeric/from pandas.api.types import is_numeric_dtype as numeric/" main_eval.py
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF

# %%
# !grep -n "numeric" main_eval.py
# Out:
# 3:from pandas.api.types import is_numeric_dtype as numeric
# 260:        mse5 = (df.mean(0, numeric_only=True)['5'], df.std(numeric_only=True)['5'])
# 261:        mse10 = (df.mean(0, numeric_only=True)['10'], df.std(numeric_only=True)['10'])
# 262:        mse20 = (df.mean(0, numeric_only=True)['20'], df.std(numeric_only=True)['20'])
# 272:        pse = (df.mean(0, numeric_only=True)['mean'], df.std(numeric_only=True)['mean'])

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG

# %%
# !sed -i "s/Argument('use_gpu', \[[0-9]\+\])/Argument('use_gpu', [1])/" ubermain.py

# %%
# !grep -n "use_gpu" ubermain.py
# Out:
# 11:    When using GPU for training (i.e. Argument 'use_gpu 1')  it is generally
# 17:    args.append(Argument('use_gpu', [1])) # may wanna use gpu here

# %%
# !sed -i "s/n_runs = [0-9]\+/n_runs = 1/" ubermain.py

# %%
# !grep -n "n_runs" ubermain.py
# Out:
# 4:def ubermain(n_runs):
# 28:    args.append(Argument('run', list(range(1, 1 + n_runs))))
# 36:    n_runs = 1
# 42:    args = ubermain(n_runs)

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" \
python Experiments/Table1/ECG/ubermain.py
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF
# 'use_gpu' flag is set.
# Will distribute tasks to GPUs automatically.
# There are not enough GPU Resources available to spawn 20 processes. Reducing number of parallel runs to 1
# Using device Tesla P100-PCIE-16GB for training (cuda:0).
# Forcing interval set by user: 10
# Epoch 1 took 15.72s | Cumulative time (h:mm:ss): 0:00:15 | Loss = 0.8747051954269409
# Epoch 2 took 15.13s | Cumulative time (h:mm:ss): 0:00:30 | Loss = 0.8907575011253357
# Epoch 3 took 15.22s | Cumulative time (h:mm:ss): 0:00:46 | Loss = 0.834093451499939
# Epoch 4 took 15.26s | Cumulative time (h:mm:ss): 0:01:01 | Loss = 0.8328145146369934
# Epoch 5 took 15.51s | Cumulative time (h:mm:ss): 0:01:16 | Loss = 0.8789836764335632
# Epoch 6 took 15.28s | Cumulative time (h:mm:ss): 0:01:32 | Loss = 0.7628544569015503
# Epoch 7 took 15.02s | Cumulative time (h:mm:ss): 0:01:47 | Loss = 0.7105631828308105
# Epoch 8 took 15.07s | Cumulative time (h:mm:ss): 0:02:02 | Loss = 0.7331055998802185
# Epoch 9 took 15.17s | Cumulative time (h:mm:ss): 0:02:17 | Loss = 0.6273519992828369
# Epoch 10 took 14.98s | Cumulative time (h:mm:ss): 0:02:32 | Loss = 0.6377360224723816
# Epoch 11 took 15.12s | Cumulative time (h:mm:ss): 0:02:47 | Loss = 0.472519189119339
# Epoch 12 took 15.09s | Cumulative time (h:mm:ss): 0:03:02 | Loss = 0.5202447772026062
# Epoch 13 took 15.12s | Cumulative time (h:mm:ss): 0:03:17 | Loss = 0.5046340227127075
# Epoch 14 took 15.06s | Cumulative time (h:mm:ss): 0:03:32 | Loss = 0.4080256521701813
# Epoch 15 took 15.21s | Cumulative time (h:mm:ss): 0:03:47 | Loss = 0.39591357111930847
# Epoch 16 took 15.37s | Cumulative time (h:mm:ss): 0:04:03 | Loss = 0.3329036235809326
# Epoch 17 took 15.1s | Cumulative time (h:mm:ss): 0:04:18 | Loss = 0.298879474401474
# Epoch 18 took 15.03s | Cumulative time (h:mm:ss): 0:04:33 | Loss = 0.26687395572662354
# Epoch 19 took 15.15s | Cumulative time (h:mm:ss): 0:04:48 | Loss = 0.27424269914627075
# Epoch 20 took 15.32s | Cumulative time (h:mm:ss): 0:05:03 | Loss = 0.19891142845153809
# Epoch 21 took 15.17s | Cumulative time (h:mm:ss): 0:05:19 | Loss = 0.2015368789434433
# Epoch 22 took 15.09s | Cumulative time (h:mm:ss): 0:05:34 | Loss = 0.1959284245967865
# Epoch 23 took 15.17s | Cumulative time (h:mm:ss): 0:05:49 | Loss = 0.18343091011047363
# Epoch 24 took 15.14s | Cumulative time (h:mm:ss): 0:06:04 | Loss = 0.17148005962371826
# Epoch 25 took 15.07s | Cumulative time (h:mm:ss): 0:06:19 | Loss = 0.1683548390865326
# 	MSE-1 0.05278016999363899
# 	MSE-5 0.29246577620506287
# 	MSE-10 0.6225458383560181
# 	MSE-20 0.9258699417114258
# 20 20000
# 	PSE 0.9042031804702313
# 	PSE per dim [0.9057270306702531, 0.8848484971553788, 0.78214787366894, 0.9551145634045941, 0.9181276149520013, 0.9745220505734435, 0.9089346328670082]
# Computing KLx-GMM
# 	KLx 1.467500925064087
# Epoch 26 took 15.07s | Cumulative time (h:mm:ss): 0:06:34 | Loss = 0.1447610855102539
# Epoch 27 took 15.72s | Cumulative time (h:mm:ss): 0:06:50 | Loss = 0.1615476757287979
# Epoch 28 took 15.97s | Cumulative time (h:mm:ss): 0:07:06 | Loss = 0.14728136360645294
# Epoch 29 took 15.65s | Cumulative time (h:mm:ss): 0:07:21 | Loss = 0.14342768490314484
# Epoch 30 took 15.27s | Cumulative time (h:mm:ss): 0:07:37 | Loss = 0.14466504752635956
# Epoch 31 took 15.51s | Cumulative time (h:mm:ss): 0:07:52 | Loss = 0.14572525024414062
# Epoch 32 took 15.4s | Cumulative time (h:mm:ss): 0:08:08 | Loss = 0.13676324486732483
# Epoch 33 took 15.39s | Cumulative time (h:mm:ss): 0:08:23 | Loss = 0.14079627394676208
# Epoch 34 took 15.19s | Cumulative time (h:mm:ss): 0:08:38 | Loss = 0.12881596386432648
# Epoch 35 took 15.2s | Cumulative time (h:mm:ss): 0:08:53 | Loss = 0.11463277786970139
# Epoch 36 took 15.15s | Cumulative time (h:mm:ss): 0:09:09 | Loss = 0.1157776489853859
# Epoch 37 took 15.1s | Cumulative time (h:mm:ss): 0:09:24 | Loss = 0.11468567699193954
# Epoch 38 took 15.35s | Cumulative time (h:mm:ss): 0:09:39 | Loss = 0.11568687111139297
# Epoch 39 took 15.45s | Cumulative time (h:mm:ss): 0:09:54 | Loss = 0.10433337837457657
# Epoch 40 took 15.4s | Cumulative time (h:mm:ss): 0:10:10 | Loss = 0.11369146406650543
# Epoch 41 took 15.22s | Cumulative time (h:mm:ss): 0:10:25 | Loss = 0.09585648030042648
# Epoch 42 took 15.38s | Cumulative time (h:mm:ss): 0:10:40 | Loss = 0.09539856016635895
# Epoch 43 took 15.01s | Cumulative time (h:mm:ss): 0:10:55 | Loss = 0.09499691426753998
# Epoch 44 took 15.19s | Cumulative time (h:mm:ss): 0:11:11 | Loss = 0.09675200283527374
# Epoch 45 took 15.14s | Cumulative time (h:mm:ss): 0:11:26 | Loss = 0.08994003385305405
# Epoch 46 took 15.09s | Cumulative time (h:mm:ss): 0:11:41 | Loss = 0.08871298283338547
# Epoch 47 took 15.08s | Cumulative time (h:mm:ss): 0:11:56 | Loss = 0.07394730299711227
# Epoch 48 took 15.08s | Cumulative time (h:mm:ss): 0:12:11 | Loss = 0.09224195778369904
# Epoch 49 took 15.12s | Cumulative time (h:mm:ss): 0:12:26 | Loss = 0.09740310907363892
# Epoch 50 took 15.04s | Cumulative time (h:mm:ss): 0:12:41 | Loss = 0.0869266539812088
# 	MSE-1 0.039323318749666214
# 	MSE-5 0.23543962836265564
# 	MSE-10 0.494561105966568
# 	MSE-20 0.6764452457427979
# 20 20000
# 	PSE 0.9000455985383077
# 	PSE per dim [0.9159952397463513, 0.9343258497918676, 0.909312589954007, 0.8873306967605975, 0.860720236799029, 0.9635064495596021, 0.8291281271566999]
# Computing KLx-GMM
# 	KLx 4.104548931121826
# Epoch 51 took 15.08s | Cumulative time (h:mm:ss): 0:12:56 | Loss = 0.07032620906829834
# Epoch 52 took 15.14s | Cumulative time (h:mm:ss): 0:13:11 | Loss = 0.06983140110969543
# Epoch 53 took 15.13s | Cumulative time (h:mm:ss): 0:13:27 | Loss = 0.07727921009063721
# Epoch 54 took 15.08s | Cumulative time (h:mm:ss): 0:13:42 | Loss = 0.06671541929244995
# Epoch 55 took 15.05s | Cumulative time (h:mm:ss): 0:13:57 | Loss = 0.07288587838411331
# Epoch 56 took 14.97s | Cumulative time (h:mm:ss): 0:14:12 | Loss = 0.06157836690545082
# Epoch 57 took 15.16s | Cumulative time (h:mm:ss): 0:14:27 | Loss = 0.0685219019651413
# Epoch 58 took 15.09s | Cumulative time (h:mm:ss): 0:14:42 | Loss = 0.061273202300071716
# Epoch 59 took 15.08s | Cumulative time (h:mm:ss): 0:14:57 | Loss = 0.06360243260860443
# Epoch 60 took 15.05s | Cumulative time (h:mm:ss): 0:15:12 | Loss = 0.06999008357524872
# Epoch 61 took 15.13s | Cumulative time (h:mm:ss): 0:15:27 | Loss = 0.04993019998073578
# Epoch 62 took 15.07s | Cumulative time (h:mm:ss): 0:15:42 | Loss = 0.06807385385036469
# Epoch 63 took 15.09s | Cumulative time (h:mm:ss): 0:15:57 | Loss = 0.052177514880895615
# Epoch 64 took 15.07s | Cumulative time (h:mm:ss): 0:16:12 | Loss = 0.07177294045686722
# Epoch 65 took 15.48s | Cumulative time (h:mm:ss): 0:16:28 | Loss = 0.05239933356642723
# Epoch 66 took 15.13s | Cumulative time (h:mm:ss): 0:16:43 | Loss = 0.05300316587090492
# Epoch 67 took 15.13s | Cumulative time (h:mm:ss): 0:16:58 | Loss = 0.055292703211307526
# Epoch 68 took 15.11s | Cumulative time (h:mm:ss): 0:17:13 | Loss = 0.06290543079376221
# Epoch 69 took 15.14s | Cumulative time (h:mm:ss): 0:17:28 | Loss = 0.04394049197435379
# Epoch 70 took 15.14s | Cumulative time (h:mm:ss): 0:17:44 | Loss = 0.046871721744537354
# Epoch 71 took 15.17s | Cumulative time (h:mm:ss): 0:17:59 | Loss = 0.040483586490154266
# Epoch 72 took 15.1s | Cumulative time (h:mm:ss): 0:18:14 | Loss = 0.059680573642253876
# Epoch 73 took 15.16s | Cumulative time (h:mm:ss): 0:18:29 | Loss = 0.07539872080087662
# Epoch 74 took 15.11s | Cumulative time (h:mm:ss): 0:18:44 | Loss = 0.05773534998297691
# Epoch 75 took 15.09s | Cumulative time (h:mm:ss): 0:18:59 | Loss = 0.04268837720155716
# 	MSE-1 0.04630441591143608
# 	MSE-5 0.22509053349494934
# 	MSE-10 0.4440612196922302
# 	MSE-20 0.5353887677192688
# 20 20000
# 	PSE 0.9014887542458282
# 	PSE per dim [0.8997179707085488, 0.880053688464642, 0.8911440001918588, 0.8846711332034461, 0.9366626608617138, 0.9223757437693254, 0.8957960825212636]
# Computing KLx-GMM
# 	KLx 4.597307205200195
# Epoch 76 took 15.19s | Cumulative time (h:mm:ss): 0:19:14 | Loss = 0.04201025515794754
# Epoch 77 took 15.12s | Cumulative time (h:mm:ss): 0:19:29 | Loss = 0.03471151739358902
# Epoch 78 took 15.11s | Cumulative time (h:mm:ss): 0:19:45 | Loss = 0.05761534720659256
# Epoch 79 took 15.0s | Cumulative time (h:mm:ss): 0:20:00 | Loss = 0.03450828045606613
# Epoch 80 took 15.12s | Cumulative time (h:mm:ss): 0:20:15 | Loss = 0.03751898929476738
# Epoch 81 took 15.09s | Cumulative time (h:mm:ss): 0:20:30 | Loss = 0.037745848298072815
# Epoch 82 took 15.19s | Cumulative time (h:mm:ss): 0:20:45 | Loss = 0.03254454955458641
# Epoch 83 took 15.09s | Cumulative time (h:mm:ss): 0:21:00 | Loss = 0.03652120381593704
# Epoch 84 took 15.13s | Cumulative time (h:mm:ss): 0:21:15 | Loss = 0.03734001889824867
# Epoch 85 took 15.11s | Cumulative time (h:mm:ss): 0:21:30 | Loss = 0.036039408296346664
# Epoch 86 took 15.2s | Cumulative time (h:mm:ss): 0:21:46 | Loss = 0.03551630303263664
# Epoch 87 took 15.46s | Cumulative time (h:mm:ss): 0:22:01 | Loss = 0.039894286543130875
# Epoch 88 took 15.27s | Cumulative time (h:mm:ss): 0:22:16 | Loss = 0.033739957958459854
# Epoch 89 took 15.14s | Cumulative time (h:mm:ss): 0:22:31 | Loss = 0.031533773988485336
# Epoch 90 took 15.16s | Cumulative time (h:mm:ss): 0:22:47 | Loss = 0.039957717061042786
# Epoch 91 took 15.11s | Cumulative time (h:mm:ss): 0:23:02 | Loss = 0.028694625943899155
# Epoch 92 took 15.02s | Cumulative time (h:mm:ss): 0:23:17 | Loss = 0.042616263031959534
# Epoch 93 took 15.03s | Cumulative time (h:mm:ss): 0:23:32 | Loss = 0.035816580057144165
# Epoch 94 took 15.04s | Cumulative time (h:mm:ss): 0:23:47 | Loss = 0.05426040291786194
# Epoch 95 took 15.01s | Cumulative time (h:mm:ss): 0:24:02 | Loss = 0.18261870741844177
# Epoch 96 took 15.02s | Cumulative time (h:mm:ss): 0:24:17 | Loss = 0.1051541194319725
# Epoch 97 took 15.04s | Cumulative time (h:mm:ss): 0:24:32 | Loss = 0.06523937731981277
# Epoch 98 took 15.05s | Cumulative time (h:mm:ss): 0:24:47 | Loss = 0.0478753037750721
# Epoch 99 took 15.04s | Cumulative time (h:mm:ss): 0:25:02 | Loss = 0.040176983922719955
# Epoch 100 took 15.01s | Cumulative time (h:mm:ss): 0:25:17 | Loss = 0.036132052540779114
# 	MSE-1 0.04508301615715027
# 	MSE-5 0.20824837684631348
# 	MSE-10 0.4353867173194885
# 	MSE-20 0.4839325547218323
# 20 20000
# 	PSE 0.873051425995847
# 	PSE per dim [0.9331066877414348, 0.7678408313944263, 0.8760062025123495, 0.8955438803849148, 0.882370935341514, 0.960771244330831, 0.7957202002654579]
# Computing KLx-GMM
# 	KLx 3.0527942180633545
# Epoch 101 took 15.08s | Cumulative time (h:mm:ss): 0:25:32 | Loss = 0.03629187121987343
# Epoch 102 took 15.1s | Cumulative time (h:mm:ss): 0:25:47 | Loss = 0.035399626940488815
# Epoch 103 took 15.11s | Cumulative time (h:mm:ss): 0:26:02 | Loss = 0.04105241224169731
# Epoch 104 took 15.09s | Cumulative time (h:mm:ss): 0:26:17 | Loss = 0.05024014785885811
# Epoch 105 took 15.25s | Cumulative time (h:mm:ss): 0:26:33 | Loss = 0.02990536019206047
# Epoch 106 took 15.27s | Cumulative time (h:mm:ss): 0:26:48 | Loss = 0.02780209667980671
# Epoch 107 took 15.11s | Cumulative time (h:mm:ss): 0:27:03 | Loss = 0.033488694578409195
# Epoch 108 took 15.09s | Cumulative time (h:mm:ss): 0:27:18 | Loss = 0.027138996869325638
# Epoch 109 took 15.08s | Cumulative time (h:mm:ss): 0:27:33 | Loss = 0.036544837057590485
# Epoch 110 took 15.51s | Cumulative time (h:mm:ss): 0:27:49 | Loss = 0.05850053206086159
# Epoch 111 took 15.11s | Cumulative time (h:mm:ss): 0:28:04 | Loss = 0.04462532326579094
# Epoch 112 took 15.01s | Cumulative time (h:mm:ss): 0:28:19 | Loss = 0.033335864543914795
# Epoch 113 took 15.03s | Cumulative time (h:mm:ss): 0:28:34 | Loss = 0.03814438730478287
# Epoch 114 took 15.12s | Cumulative time (h:mm:ss): 0:28:49 | Loss = 0.023860067129135132
# Epoch 115 took 15.19s | Cumulative time (h:mm:ss): 0:29:04 | Loss = 0.02524528279900551
# Epoch 116 took 15.09s | Cumulative time (h:mm:ss): 0:29:19 | Loss = 0.022671177983283997
# Epoch 117 took 14.96s | Cumulative time (h:mm:ss): 0:29:34 | Loss = 0.029670270159840584
# Epoch 118 took 15.0s | Cumulative time (h:mm:ss): 0:29:49 | Loss = 0.02055020071566105
# Epoch 119 took 15.1s | Cumulative time (h:mm:ss): 0:30:04 | Loss = 0.02980242669582367
# Epoch 120 took 15.08s | Cumulative time (h:mm:ss): 0:30:19 | Loss = 0.037671059370040894
# Epoch 121 took 15.05s | Cumulative time (h:mm:ss): 0:30:34 | Loss = 0.02906806766986847
# Epoch 122 took 15.08s | Cumulative time (h:mm:ss): 0:30:49 | Loss = 0.02467355690896511
# Epoch 123 took 15.06s | Cumulative time (h:mm:ss): 0:31:04 | Loss = 0.024942580610513687
# Epoch 124 took 15.1s | Cumulative time (h:mm:ss): 0:31:20 | Loss = 0.03944598510861397
# Epoch 125 took 15.48s | Cumulative time (h:mm:ss): 0:31:35 | Loss = 0.02990018017590046
# 	MSE-1 0.042205002158880234
# 	MSE-5 0.19978688657283783
# 	MSE-10 0.4063940644264221
# 	MSE-20 0.4227050840854645
# 20 20000
# 	PSE 0.9246606391030792
# 	PSE per dim [0.8890012100380252, 0.9461218164376278, 0.9377259556810535, 0.9051699728656376, 0.9474268569400207, 0.9150392947830629, 0.9321393669761265]
# Computing KLx-GMM
# 	KLx 1.6522789001464844
# Epoch 126 took 14.94s | Cumulative time (h:mm:ss): 0:31:50 | Loss = 0.02522505819797516
# Epoch 127 took 14.97s | Cumulative time (h:mm:ss): 0:32:05 | Loss = 0.02462402544915676
# Epoch 128 took 14.97s | Cumulative time (h:mm:ss): 0:32:20 | Loss = 0.02232813835144043
# Epoch 129 took 15.0s | Cumulative time (h:mm:ss): 0:32:35 | Loss = 0.026065438985824585
# Epoch 130 took 14.92s | Cumulative time (h:mm:ss): 0:32:50 | Loss = 0.02367839589715004
# Epoch 131 took 14.92s | Cumulative time (h:mm:ss): 0:33:05 | Loss = 0.018789008259773254
# Epoch 132 took 14.92s | Cumulative time (h:mm:ss): 0:33:20 | Loss = 0.02088923752307892
# Epoch 133 took 14.94s | Cumulative time (h:mm:ss): 0:33:35 | Loss = 0.02662377990782261
# Epoch 134 took 14.93s | Cumulative time (h:mm:ss): 0:33:50 | Loss = 0.02174869365990162
# Epoch 135 took 14.98s | Cumulative time (h:mm:ss): 0:34:05 | Loss = 0.01955590769648552
# Epoch 136 took 15.01s | Cumulative time (h:mm:ss): 0:34:20 | Loss = 0.021115107461810112
# Epoch 137 took 14.95s | Cumulative time (h:mm:ss): 0:34:34 | Loss = 0.018564043566584587
# Epoch 138 took 15.27s | Cumulative time (h:mm:ss): 0:34:50 | Loss = 0.018998434767127037
# Epoch 139 took 15.07s | Cumulative time (h:mm:ss): 0:35:05 | Loss = 0.026579558849334717
# Epoch 140 took 14.98s | Cumulative time (h:mm:ss): 0:35:20 | Loss = 0.019201001152396202
# Epoch 141 took 14.98s | Cumulative time (h:mm:ss): 0:35:35 | Loss = 0.024587132036685944
# Epoch 142 took 14.93s | Cumulative time (h:mm:ss): 0:35:50 | Loss = 0.016225311905145645
# Epoch 143 took 15.01s | Cumulative time (h:mm:ss): 0:36:05 | Loss = 0.022206827998161316
# Epoch 144 took 15.0s | Cumulative time (h:mm:ss): 0:36:20 | Loss = 0.023502860218286514
# Epoch 145 took 14.94s | Cumulative time (h:mm:ss): 0:36:35 | Loss = 0.02078903652727604
# Epoch 146 took 14.96s | Cumulative time (h:mm:ss): 0:36:50 | Loss = 0.01904059760272503
# Epoch 147 took 15.29s | Cumulative time (h:mm:ss): 0:37:05 | Loss = 0.021329933777451515
# Epoch 148 took 15.57s | Cumulative time (h:mm:ss): 0:37:20 | Loss = 0.020715761929750443
# Epoch 149 took 15.36s | Cumulative time (h:mm:ss): 0:37:36 | Loss = 0.031427379697561264
# Epoch 150 took 15.36s | Cumulative time (h:mm:ss): 0:37:51 | Loss = 0.020871730521321297
# 	MSE-1 0.038574449717998505
# 	MSE-5 0.19261696934700012
# 	MSE-10 0.3947394788265228
# 	MSE-20 0.3967735469341278
# 20 20000
# 	PSE 0.8962896692348572
# 	PSE per dim [0.9367112794436748, 0.850168661300515, 0.8743365468931987, 0.8407769900555432, 0.9260037748406184, 0.95335503214252, 0.8926753999679302]
# Computing KLx-GMM
# 	KLx 10.942273139953613
# Epoch 151 took 15.25s | Cumulative time (h:mm:ss): 0:38:06 | Loss = 0.019228341057896614
# Epoch 152 took 15.43s | Cumulative time (h:mm:ss): 0:38:22 | Loss = 0.026653235778212547
# Epoch 153 took 15.14s | Cumulative time (h:mm:ss): 0:38:37 | Loss = 0.0219328124076128
# Epoch 154 took 15.54s | Cumulative time (h:mm:ss): 0:38:53 | Loss = 0.016675245016813278
# Epoch 155 took 15.45s | Cumulative time (h:mm:ss): 0:39:08 | Loss = 0.01798398233950138
# Epoch 156 took 15.46s | Cumulative time (h:mm:ss): 0:39:23 | Loss = 0.015109031461179256
# Epoch 157 took 15.07s | Cumulative time (h:mm:ss): 0:39:39 | Loss = 0.019173312932252884
# Epoch 158 took 15.05s | Cumulative time (h:mm:ss): 0:39:54 | Loss = 0.02441108040511608
# Epoch 159 took 15.05s | Cumulative time (h:mm:ss): 0:40:09 | Loss = 0.01781643182039261
# Epoch 160 took 14.93s | Cumulative time (h:mm:ss): 0:40:24 | Loss = 0.02563767321407795
# Epoch 161 took 15.06s | Cumulative time (h:mm:ss): 0:40:39 | Loss = 0.019681863486766815
# Epoch 162 took 15.05s | Cumulative time (h:mm:ss): 0:40:54 | Loss = 0.017477955669164658
# Epoch 163 took 15.14s | Cumulative time (h:mm:ss): 0:41:09 | Loss = 0.020020155236124992
# Epoch 164 took 14.95s | Cumulative time (h:mm:ss): 0:41:24 | Loss = 0.015863191336393356
# Epoch 165 took 15.11s | Cumulative time (h:mm:ss): 0:41:39 | Loss = 0.017686065286397934
# Epoch 166 took 14.98s | Cumulative time (h:mm:ss): 0:41:54 | Loss = 0.021084973588585854
# Epoch 167 took 14.9s | Cumulative time (h:mm:ss): 0:42:09 | Loss = 0.028253622353076935
# Epoch 168 took 14.99s | Cumulative time (h:mm:ss): 0:42:24 | Loss = 0.016778316348791122
# Epoch 169 took 15.03s | Cumulative time (h:mm:ss): 0:42:39 | Loss = 0.014997024089097977
# Epoch 170 took 14.9s | Cumulative time (h:mm:ss): 0:42:54 | Loss = 0.01712029054760933
# Epoch 171 took 14.82s | Cumulative time (h:mm:ss): 0:43:09 | Loss = 0.017386438325047493
# Epoch 172 took 14.91s | Cumulative time (h:mm:ss): 0:43:23 | Loss = 0.018331991508603096
# Epoch 173 took 15.03s | Cumulative time (h:mm:ss): 0:43:38 | Loss = 0.015553118661046028
# Epoch 174 took 14.97s | Cumulative time (h:mm:ss): 0:43:53 | Loss = 0.02081953175365925
# Epoch 175 took 15.02s | Cumulative time (h:mm:ss): 0:44:08 | Loss = 0.01915171556174755
# 	MSE-1 0.03507866710424423
# 	MSE-5 0.18461710214614868
# 	MSE-10 0.37160423398017883
# 	MSE-20 0.35897567868232727
# 20 20000
# 	PSE 0.924466301640137
# 	PSE per dim [0.906510316367123, 0.945210758909383, 0.9286773957655774, 0.941799981085526, 0.8448097684871276, 0.9430804471304092, 0.961175443735812]
# Computing KLx-GMM
# 	KLx 1.2317326068878174
# Epoch 176 took 15.15s | Cumulative time (h:mm:ss): 0:44:24 | Loss = 0.015918610617518425
# Epoch 177 took 15.14s | Cumulative time (h:mm:ss): 0:44:39 | Loss = 0.022537676617503166
# Epoch 178 took 15.09s | Cumulative time (h:mm:ss): 0:44:54 | Loss = 0.014620666392147541
# Epoch 179 took 15.13s | Cumulative time (h:mm:ss): 0:45:09 | Loss = 0.019233837723731995
# Epoch 180 took 14.89s | Cumulative time (h:mm:ss): 0:45:24 | Loss = 0.016506196931004524
# Epoch 181 took 14.97s | Cumulative time (h:mm:ss): 0:45:39 | Loss = 0.01629495434463024
# Epoch 182 took 15.07s | Cumulative time (h:mm:ss): 0:45:54 | Loss = 0.014373445883393288
# Epoch 183 took 15.12s | Cumulative time (h:mm:ss): 0:46:09 | Loss = 0.016290655359625816
# Epoch 184 took 14.96s | Cumulative time (h:mm:ss): 0:46:24 | Loss = 0.01833392307162285
# Epoch 185 took 14.98s | Cumulative time (h:mm:ss): 0:46:39 | Loss = 0.01573760062456131
# Epoch 186 took 15.03s | Cumulative time (h:mm:ss): 0:46:54 | Loss = 0.018221711739897728
# Epoch 187 took 15.11s | Cumulative time (h:mm:ss): 0:47:09 | Loss = 0.020382681861519814
# Epoch 188 took 15.0s | Cumulative time (h:mm:ss): 0:47:24 | Loss = 0.02092449553310871
# Epoch 189 took 15.06s | Cumulative time (h:mm:ss): 0:47:39 | Loss = 0.07720035314559937
# Epoch 190 took 15.02s | Cumulative time (h:mm:ss): 0:47:54 | Loss = 0.030693987384438515
# Epoch 191 took 15.25s | Cumulative time (h:mm:ss): 0:48:09 | Loss = 0.023224087432026863
# Epoch 192 took 15.45s | Cumulative time (h:mm:ss): 0:48:25 | Loss = 0.01755223609507084
# Epoch 193 took 15.15s | Cumulative time (h:mm:ss): 0:48:40 | Loss = 0.025607168674468994
# Epoch 194 took 15.26s | Cumulative time (h:mm:ss): 0:48:55 | Loss = 0.018772250041365623
# Epoch 195 took 15.23s | Cumulative time (h:mm:ss): 0:49:10 | Loss = 0.020570358261466026
# Epoch 196 took 15.53s | Cumulative time (h:mm:ss): 0:49:26 | Loss = 0.013779904693365097
# Epoch 197 took 15.2s | Cumulative time (h:mm:ss): 0:49:41 | Loss = 0.01824585162103176
# Epoch 198 took 15.31s | Cumulative time (h:mm:ss): 0:49:57 | Loss = 0.022213147953152657
# Epoch 199 took 15.14s | Cumulative time (h:mm:ss): 0:50:12 | Loss = 0.01917833834886551
# Epoch 200 took 15.16s | Cumulative time (h:mm:ss): 0:50:27 | Loss = 0.017147039994597435
# 	MSE-1 0.03465447202324867
# 	MSE-5 0.1773993819952011
# 	MSE-10 0.36023446917533875
# 	MSE-20 0.35605648159980774
# 20 20000
# 	PSE 0.9456453056008947
# 	PSE per dim [0.9466347125246285, 0.9364347104472492, 0.9458757668464085, 0.9293334866278907, 0.93738251227316, 0.960262091452987, 0.9635938590339387]
# Computing KLx-GMM
# 	KLx 0.6809163689613342
# Epoch 201 took 15.25s | Cumulative time (h:mm:ss): 0:50:42 | Loss = 0.02049214020371437
# Epoch 202 took 15.26s | Cumulative time (h:mm:ss): 0:50:57 | Loss = 0.017461303621530533
# Epoch 203 took 15.35s | Cumulative time (h:mm:ss): 0:51:13 | Loss = 0.02454477921128273
# Epoch 204 took 15.23s | Cumulative time (h:mm:ss): 0:51:28 | Loss = 0.019560642540454865
# Epoch 205 took 15.33s | Cumulative time (h:mm:ss): 0:51:43 | Loss = 0.013159777037799358
# Epoch 206 took 15.33s | Cumulative time (h:mm:ss): 0:51:59 | Loss = 0.01772337779402733
# Epoch 207 took 15.52s | Cumulative time (h:mm:ss): 0:52:14 | Loss = 0.018132535740733147
# Epoch 208 took 15.71s | Cumulative time (h:mm:ss): 0:52:30 | Loss = 0.022543208673596382
# Epoch 209 took 15.77s | Cumulative time (h:mm:ss): 0:52:46 | Loss = 0.017579715698957443
# Epoch 210 took 16.08s | Cumulative time (h:mm:ss): 0:53:02 | Loss = 0.01859780214726925
# Epoch 211 took 15.86s | Cumulative time (h:mm:ss): 0:53:18 | Loss = 0.016514794901013374
# Epoch 212 took 15.75s | Cumulative time (h:mm:ss): 0:53:33 | Loss = 0.018791407346725464
# Epoch 213 took 15.72s | Cumulative time (h:mm:ss): 0:53:49 | Loss = 0.01580536738038063
# Epoch 214 took 15.82s | Cumulative time (h:mm:ss): 0:54:05 | Loss = 0.01928718574345112
# Epoch 215 took 15.7s | Cumulative time (h:mm:ss): 0:54:21 | Loss = 0.017854444682598114
# Epoch 216 took 15.81s | Cumulative time (h:mm:ss): 0:54:36 | Loss = 0.02140788920223713
# Epoch 217 took 15.99s | Cumulative time (h:mm:ss): 0:54:52 | Loss = 0.013702585361897945
# Epoch 218 took 15.75s | Cumulative time (h:mm:ss): 0:55:08 | Loss = 0.013243152759969234
# Epoch 219 took 15.72s | Cumulative time (h:mm:ss): 0:55:24 | Loss = 0.016502277925610542
# Epoch 220 took 15.64s | Cumulative time (h:mm:ss): 0:55:39 | Loss = 0.01372256688773632
# Epoch 221 took 15.83s | Cumulative time (h:mm:ss): 0:55:55 | Loss = 0.016997413709759712
# Epoch 222 took 15.73s | Cumulative time (h:mm:ss): 0:56:11 | Loss = 0.021509798243641853
# Epoch 223 took 15.75s | Cumulative time (h:mm:ss): 0:56:27 | Loss = 0.019490545615553856
# Epoch 224 took 15.72s | Cumulative time (h:mm:ss): 0:56:42 | Loss = 0.016577789559960365
# Epoch 225 took 15.67s | Cumulative time (h:mm:ss): 0:56:58 | Loss = 0.03032832033932209
# 	MSE-1 0.03353126719594002
# 	MSE-5 0.17586061358451843
# 	MSE-10 0.35843732953071594
# 	MSE-20 0.3699171245098114
# 20 20000
# 	PSE 0.8878115052593104
# 	PSE per dim [0.905415718785758, 0.9286248560747037, 0.8578424054811309, 0.8477712332091538, 0.87464138457937, 0.8934921974620338, 0.9068927412230237]
# Computing KLx-GMM
# 	KLx 0.5766900777816772
# Epoch 226 took 15.62s | Cumulative time (h:mm:ss): 0:57:14 | Loss = 0.017872758209705353
# Epoch 227 took 15.63s | Cumulative time (h:mm:ss): 0:57:29 | Loss = 0.02036929316818714
# Epoch 228 took 15.8s | Cumulative time (h:mm:ss): 0:57:45 | Loss = 0.014785083942115307
# Epoch 229 took 15.71s | Cumulative time (h:mm:ss): 0:58:01 | Loss = 0.014349285513162613
# Epoch 230 took 15.73s | Cumulative time (h:mm:ss): 0:58:17 | Loss = 0.01345912367105484
# Epoch 231 took 15.73s | Cumulative time (h:mm:ss): 0:58:32 | Loss = 0.013166015036404133
# Epoch 232 took 15.7s | Cumulative time (h:mm:ss): 0:58:48 | Loss = 0.03143260255455971
# Epoch 233 took 15.66s | Cumulative time (h:mm:ss): 0:59:04 | Loss = 0.012722163461148739
# Epoch 234 took 15.92s | Cumulative time (h:mm:ss): 0:59:20 | Loss = 0.014747228473424911
# Epoch 235 took 15.62s | Cumulative time (h:mm:ss): 0:59:35 | Loss = 0.01571553945541382
# Epoch 236 took 15.64s | Cumulative time (h:mm:ss): 0:59:51 | Loss = 0.019520387053489685
# Epoch 237 took 15.57s | Cumulative time (h:mm:ss): 1:00:06 | Loss = 0.016660725697875023
# Epoch 238 took 15.6s | Cumulative time (h:mm:ss): 1:00:22 | Loss = 0.014094922691583633
# Epoch 239 took 15.69s | Cumulative time (h:mm:ss): 1:00:38 | Loss = 0.016667239367961884
# Epoch 240 took 15.69s | Cumulative time (h:mm:ss): 1:00:53 | Loss = 0.015329974703490734
# Epoch 241 took 15.62s | Cumulative time (h:mm:ss): 1:01:09 | Loss = 0.01639629900455475
# Epoch 242 took 15.72s | Cumulative time (h:mm:ss): 1:01:25 | Loss = 0.019572163000702858
# Epoch 243 took 15.7s | Cumulative time (h:mm:ss): 1:01:40 | Loss = 0.02015058882534504
# Epoch 244 took 15.76s | Cumulative time (h:mm:ss): 1:01:56 | Loss = 0.017610657960176468
# Epoch 245 took 15.74s | Cumulative time (h:mm:ss): 1:02:12 | Loss = 0.013562036678195
# Epoch 246 took 15.68s | Cumulative time (h:mm:ss): 1:02:28 | Loss = 0.018155869096517563
# Epoch 247 took 15.68s | Cumulative time (h:mm:ss): 1:02:43 | Loss = 0.018964972347021103
# Epoch 248 took 15.6s | Cumulative time (h:mm:ss): 1:02:59 | Loss = 0.01969052106142044
# Epoch 249 took 15.7s | Cumulative time (h:mm:ss): 1:03:15 | Loss = 0.0173176322132349
# Epoch 250 took 15.79s | Cumulative time (h:mm:ss): 1:03:30 | Loss = 0.017220117151737213
# 	MSE-1 0.03382731229066849
# 	MSE-5 0.17061780393123627
# 	MSE-10 0.34064242243766785
# 	MSE-20 0.33357998728752136
# 20 20000
# 	PSE 0.8096281132599081
# 	PSE per dim [0.7461591980796908, 0.7510206867200827, 0.7915497682382903, 0.7810804722500242, 0.8770676626692153, 0.8513779700932893, 0.8691410347687651]
# Computing KLx-GMM
# 	KLx 0.7266877293586731
# Epoch 251 took 15.88s | Cumulative time (h:mm:ss): 1:03:46 | Loss = 0.018482042476534843
# Epoch 252 took 15.7s | Cumulative time (h:mm:ss): 1:04:02 | Loss = 0.01347212865948677
# Epoch 253 took 15.68s | Cumulative time (h:mm:ss): 1:04:18 | Loss = 0.013561567291617393
# Epoch 254 took 15.7s | Cumulative time (h:mm:ss): 1:04:33 | Loss = 0.017364799976348877
# Epoch 255 took 15.75s | Cumulative time (h:mm:ss): 1:04:49 | Loss = 0.012565850280225277
# Epoch 256 took 15.75s | Cumulative time (h:mm:ss): 1:05:05 | Loss = 0.015567602589726448
# Epoch 257 took 15.55s | Cumulative time (h:mm:ss): 1:05:20 | Loss = 0.01258754637092352
# Epoch 258 took 15.71s | Cumulative time (h:mm:ss): 1:05:36 | Loss = 0.02173999510705471
# Epoch 259 took 15.69s | Cumulative time (h:mm:ss): 1:05:52 | Loss = 0.013663889840245247
# Epoch 260 took 15.65s | Cumulative time (h:mm:ss): 1:06:07 | Loss = 0.016020283102989197
# Epoch 261 took 15.6s | Cumulative time (h:mm:ss): 1:06:23 | Loss = 0.015497760847210884
# Epoch 262 took 15.71s | Cumulative time (h:mm:ss): 1:06:39 | Loss = 0.023093881085515022
# Epoch 263 took 15.73s | Cumulative time (h:mm:ss): 1:06:55 | Loss = 0.011589767411351204
# Epoch 264 took 15.56s | Cumulative time (h:mm:ss): 1:07:10 | Loss = 0.05641685053706169
# Epoch 265 took 15.73s | Cumulative time (h:mm:ss): 1:07:26 | Loss = 0.02295505627989769
# Epoch 266 took 15.67s | Cumulative time (h:mm:ss): 1:07:41 | Loss = 0.02387234754860401
# Epoch 267 took 15.73s | Cumulative time (h:mm:ss): 1:07:57 | Loss = 0.016036057844758034
# Epoch 268 took 15.68s | Cumulative time (h:mm:ss): 1:08:13 | Loss = 0.012799584306776524
# Epoch 269 took 16.08s | Cumulative time (h:mm:ss): 1:08:29 | Loss = 0.011861110106110573
# Epoch 270 took 15.81s | Cumulative time (h:mm:ss): 1:08:45 | Loss = 0.015399324707686901
# Epoch 271 took 15.81s | Cumulative time (h:mm:ss): 1:09:01 | Loss = 0.012948624789714813
# Epoch 272 took 15.84s | Cumulative time (h:mm:ss): 1:09:16 | Loss = 0.012053950689733028
# Epoch 273 took 15.73s | Cumulative time (h:mm:ss): 1:09:32 | Loss = 0.016773905605077744
# Epoch 274 took 15.71s | Cumulative time (h:mm:ss): 1:09:48 | Loss = 0.053786080330610275
# Epoch 275 took 16.04s | Cumulative time (h:mm:ss): 1:10:04 | Loss = 0.01619226671755314
# 	MSE-1 0.03302907571196556
# 	MSE-5 0.17514429986476898
# 	MSE-10 0.3328677713871002
# 	MSE-20 0.3126896321773529
# 20 20000
# 	PSE 0.9248793141793984
# 	PSE per dim [0.8798713773119173, 0.9193910039015957, 0.9083317666582303, 0.9309568555287601, 0.9372560471532069, 0.9541464053436967, 0.9442017433583819]
# Computing KLx-GMM
# 	KLx 0.9934049844741821
# Epoch 276 took 15.7s | Cumulative time (h:mm:ss): 1:10:20 | Loss = 0.015648754313588142
# Epoch 277 took 15.7s | Cumulative time (h:mm:ss): 1:10:35 | Loss = 0.014022724702954292
# Epoch 278 took 15.68s | Cumulative time (h:mm:ss): 1:10:51 | Loss = 0.018046390265226364
# Epoch 279 took 15.74s | Cumulative time (h:mm:ss): 1:11:07 | Loss = 0.017393680289387703
# Epoch 280 took 15.61s | Cumulative time (h:mm:ss): 1:11:22 | Loss = 0.015740899369120598
# Epoch 281 took 15.65s | Cumulative time (h:mm:ss): 1:11:38 | Loss = 0.0159236341714859
# Epoch 282 took 15.72s | Cumulative time (h:mm:ss): 1:11:54 | Loss = 0.016847215592861176
# Epoch 283 took 16.09s | Cumulative time (h:mm:ss): 1:12:10 | Loss = 0.014712518081068993
# Epoch 284 took 15.76s | Cumulative time (h:mm:ss): 1:12:26 | Loss = 0.014623301103711128
# Epoch 285 took 15.83s | Cumulative time (h:mm:ss): 1:12:41 | Loss = 0.016733361408114433
# Epoch 286 took 15.62s | Cumulative time (h:mm:ss): 1:12:57 | Loss = 0.014534208923578262
# Epoch 287 took 15.63s | Cumulative time (h:mm:ss): 1:13:13 | Loss = 0.014005725271999836
# Epoch 288 took 15.78s | Cumulative time (h:mm:ss): 1:13:28 | Loss = 0.015756577253341675
# Epoch 289 took 15.63s | Cumulative time (h:mm:ss): 1:13:44 | Loss = 0.014934162609279156
# Epoch 290 took 15.74s | Cumulative time (h:mm:ss): 1:14:00 | Loss = 0.025418469682335854
# Epoch 291 took 15.72s | Cumulative time (h:mm:ss): 1:14:15 | Loss = 0.010183287784457207
# Epoch 292 took 15.72s | Cumulative time (h:mm:ss): 1:14:31 | Loss = 0.015008561313152313
# Epoch 293 took 15.66s | Cumulative time (h:mm:ss): 1:14:47 | Loss = 0.01608855277299881
# Epoch 294 took 15.89s | Cumulative time (h:mm:ss): 1:15:03 | Loss = 0.015075447969138622
# Epoch 295 took 16.16s | Cumulative time (h:mm:ss): 1:15:19 | Loss = 0.014865855686366558
# Epoch 296 took 15.93s | Cumulative time (h:mm:ss): 1:15:35 | Loss = 0.01669382117688656
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG/ubermain.py", line 43, in <module>
#     run_settings(*create_tasks_from_arguments(args, n_proc_per_gpu, n_cpu))
#   File "/kaggle/working/dendPLRNN/BPTT_TF/multitasking.py", line 146, in run_settings
#     pool.map(process_task, tasks, chunksize=1)
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 367, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 768, in get
#     self.wait(timeout)
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 765, in wait
#     self._event.wait(timeout)
#   File "/usr/lib/python3.11/threading.py", line 629, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/threading.py", line 327, in wait
#     waiter.acquire()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     main(get_args())
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#     train(args)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#     training_algorithm.train()
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 100, in train
#     loss.backward()
#   File "/usr/local/lib/python3.11/dist-packages/torch/_tensor.py", line 626, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py", line 347, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !find /kaggle/working -type f -name "pred_test.npy"

# %%
# !ls /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG/results
# Out:
# ls: cannot access '/kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG/results': No such file or directory

# %%
# !find /kaggle/working/dendPLRNN/BPTT_TF -maxdepth 4 -type d -name "run*"

# %%
# !find /kaggle/working/dendPLRNN/BPTT_TF -type d -name "run*" | sort

# %%
# !find /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/EEG -maxdepth 4 -type f \( -name "*.npy" -o -name "*.txt" \)
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/EEG/data/EEG_test.npy
# /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/EEG/data/EEG_train.npy

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF

# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" \
python main_eval.py \
--exp_folder Experiments/Table1/EEG \
--device cuda
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF
# usage: main_eval.py [-h] [--results_path RESULTS_PATH]
# main_eval.py: error: unrecognized arguments: --exp_folder Experiments/Table1/EEG --device cuda

# %%
# !find /kaggle/working/dendPLRNN/BPTT_TF -type d -name "run*" | sort

# %%
# SHOW LIVE Python variables in session
who
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_417/2625134345.py in <cell line: 0>()
#       1 # SHOW LIVE Python variables in session
# ----> 2 who
#
# NameError: name 'who' is not defined

# %%
# %who
# Out:
# sys

# %%
# %who
# Out:
# sys

# %%
# %load /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG/ubermain.py
from multitasking import *


def ubermain(n_runs):
    """
    Specify the argument choices you want to be tested here in list format:
    e.g. args.append(Argument('dim_z', [5, 6], add_to_name_as='z'))
    will test for dimensions 5 and 6 and save experiments under z5 and z6.
    Possible Arguments can be found in main.py
    
    When using GPU for training (i.e. Argument 'use_gpu 1')  it is generally
    not necessary to specify device ids, tasks will be distributed automatically.
    """
    args = []
    args.append(Argument('experiment', ['ECG']))
    args.append(Argument('data_path', ['Experiments/Table1/ECG/data/ECG_train.npy']))
    args.append(Argument('use_gpu', [1])) # may wanna use gpu here
    args.append(Argument('dim_z', [30], add_to_name_as="M"))
    args.append(Argument('n_bases', [50], add_to_name_as="B"))
    args.append(Argument('fix_obs_model', [1]))
    args.append(Argument('mean_centering', [0]))
    args.append(Argument('learn_z0', [1]))
    args.append(Argument('n_epochs', [5000]))
    args.append(Argument('teacher_forcing_interval', [10], add_to_name_as="tau"))
    args.append(Argument('seq_len', [500], add_to_name_as="T"))
    args.append(Argument('latent_model', ['clipped-PLRNN']))
    args.append(Argument('learning_rate', [1e-3]))
    args.append(Argument('run', list(range(1, 1 + n_runs))))
    return args


if __name__ == '__main__':
    import os
    os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
    # number of runs for each experiment
    n_runs = 1
    # number of runs to run in parallel
    n_cpu = 20
    # number of processes run parallel on a single GPU
    n_proc_per_gpu = 1

    args = ubermain(n_runs)
    run_settings(*create_tasks_from_arguments(args, n_proc_per_gpu, n_cpu))

# %%
# Correct multitasking import for PLRNN experiments
from bptt.multitasking import Argument, run_settings, create_tasks_from_arguments


def ubermain(n_runs):
    args = []
    args.append(Argument('experiment', ['ECG']))
    args.append(Argument('data_path', ['Experiments/Table1/ECG/data/ECG_train.npy']))
    args.append(Argument('use_gpu', [1]))
    args.append(Argument('dim_z', [30], add_to_name_as="M"))
    args.append(Argument('n_bases', [50], add_to_name_as="B"))
    args.append(Argument('fix_obs_model', [1]))
    args.append(Argument('mean_centering', [0]))
    args.append(Argument('learn_z0', [1]))
    args.append(Argument('n_epochs', [5000]))       # <== If you want 250, change here
    args.append(Argument('teacher_forcing_interval', [10], add_to_name_as="tau"))
    args.append(Argument('seq_len', [500], add_to_name_as="T"))
    args.append(Argument('latent_model', ['clipped-PLRNN']))
    args.append(Argument('learning_rate', [1e-3]))
    args.append(Argument('run', list(range(1, 1 + n_runs))))
    return args


if __name__ == '__main__':
    import os
    os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
    n_runs = 1
    n_cpu = 20
    n_proc_per_gpu = 1

    args = ubermain(n_runs)
    run_settings(*create_tasks_from_arguments(args, n_proc_per_gpu, n_cpu))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_417/2747583476.py in <cell line: 0>()
#       1 # Correct multitasking import for PLRNN experiments
# ----> 2 from bptt.multitasking import Argument, run_settings, create_tasks_from_arguments
#       3
#       4
#       5 def ubermain(n_runs):
#
# ModuleNotFoundError: No module named 'bptt.multitasking'

# %%
# %load /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG/ubermain.py
from multitasking import *


def ubermain(n_runs):
    """
    Specify the argument choices you want to be tested here in list format:
    e.g. args.append(Argument('dim_z', [5, 6], add_to_name_as='z'))
    will test for dimensions 5 and 6 and save experiments under z5 and z6.
    Possible Arguments can be found in main.py
    
    When using GPU for training (i.e. Argument 'use_gpu 1')  it is generally
    not necessary to specify device ids, tasks will be distributed automatically.
    """
    args = []
    args.append(Argument('experiment', ['ECG']))
    args.append(Argument('data_path', ['Experiments/Table1/ECG/data/ECG_train.npy']))
    args.append(Argument('use_gpu', [1])) # may wanna use gpu here
    args.append(Argument('dim_z', [30], add_to_name_as="M"))
    args.append(Argument('n_bases', [50], add_to_name_as="B"))
    args.append(Argument('fix_obs_model', [1]))
    args.append(Argument('mean_centering', [0]))
    args.append(Argument('learn_z0', [1]))
    args.append(Argument('n_epochs', [5000]))
    args.append(Argument('teacher_forcing_interval', [10], add_to_name_as="tau"))
    args.append(Argument('seq_len', [500], add_to_name_as="T"))
    args.append(Argument('latent_model', ['clipped-PLRNN']))
    args.append(Argument('learning_rate', [1e-3]))
    args.append(Argument('run', list(range(1, 1 + n_runs))))
    return args


if __name__ == '__main__':
    import os
    os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
    # number of runs for each experiment
    n_runs = 1
    # number of runs to run in parallel
    n_cpu = 20
    # number of processes run parallel on a single GPU
    n_proc_per_gpu = 1

    args = ubermain(n_runs)
    run_settings(*create_tasks_from_arguments(args, n_proc_per_gpu, n_cpu))

# %%
python   using GPU memory
# Out:
#   File "/tmp/ipykernel_417/1470087519.py", line 1
#     python   using GPU memory
#              ^
# SyntaxError: invalid syntax

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" \
python Experiments/Table1/EEG/ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" python Experiments/Table1/ECG/ubermain.py
# Out:
# /kaggle/working/dendPLRNN/BPTT_TF
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Training on cpu with 1 threads.
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Forcing interval set by user: 10
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# Forcing interval set by user: 10
# Training on cpu with 1 threads.
# Forcing interval set by user: 10
# ^C
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG/ubermain.py", line 43, in <module>
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     main(get_args())
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#     train(args)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#     training_algorithm.train()
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#     main(get_args())
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     main(get_args())
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#     train(args)
#     train(args)
#     pred = self.model(inp, self.tau)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#     training_algorithm.train()
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#     pred = self.model(inp, self.tau)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     run_settings(*create_tasks_from_arguments(args, n_proc_per_gpu, n_cpu))
#   File "/kaggle/working/dendPLRNN/BPTT_TF/multitasking.py", line 146, in run_settings
#     pool.map(process_task, tasks, chunksize=1)
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 367, in map
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     main(get_args())
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     main(get_args())
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#     training_algorithm.train()
#     train(args)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#     training_algorithm.train()
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#     pred = self.model(inp, self.tau)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     pred = self.model(inp, self.tau)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#     main(get_args())
#     train(args)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#     train(args)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#     training_algorithm.train()
#     return self._call_impl(*args, **kwargs)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     pred = self.model(inp, self.tau)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#     training_algorithm.train()
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#     pred = self.model(inp, self.tau)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 768, in get
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     self.wait(timeout)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 765, in wait
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     hidden_out = self.latent_model(x, tau, z0, B)
#     self._event.wait(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#   File "/usr/lib/python3.11/threading.py", line 629, in wait
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     hidden_out = self.latent_model(x, tau, z0, B)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     main(get_args())
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     train(args)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#     training_algorithm.train()
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     pred = self.model(inp, self.tau)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     hidden_out = self.latent_model(x, tau, z0, B)
#     return forward_call(*args, **kwargs)
# Traceback (most recent call last):
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 219, in <module>
#     main(get_args())
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 215, in main
#     train(args)
#   File "/kaggle/working/dendPLRNN/BPTT_TF/main.py", line 210, in train
#     training_algorithm.train()
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/bptt_algorithm.py", line 97, in train
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     pred = self.model(inp, self.tau)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     hidden_out = self.latent_model(x, tau, z0, B)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     hidden_out = self.latent_model(x, tau, z0, B)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     hidden_out = self.latent_model(x, tau, z0, B)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/models.py", line 40, in forward
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     hidden_out = self.latent_model(x, tau, z0, B)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     z = self.latent_step(z, *params)
#     z = self.latent_step(z, *params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     return forward_call(*args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#     z = self.latent_step(z, *params)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     z = self.latent_step(z, *params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 254, in forward
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#     be_clip = tc.sum(alphas * (tc.relu(z_norm + thetas) - tc.relu(z_norm)), dim=-1)
#     z = self.latent_step(z, *params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#                                ^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#     hidden_out = self.latent_model(x, tau, z0, B)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#     z = self.latent_step(z, *params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     z = self.latent_step(z, *params)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#         ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1915, in __getattr__
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#
# KeyboardInterrupt
#     return forward_call(*args, **kwargs)
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 253, in forward
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/threading.py", line 327, in wait
#     z_norm = self.norm(z).unsqueeze(-1)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#     waiter.acquire()
# KeyboardInterrupt
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 254, in forward
#     be_clip = tc.sum(alphas * (tc.relu(z_norm + thetas) - tc.relu(z_norm)), dim=-1)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#     return forward_call(*args, **kwargs)
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 254, in forward
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 254, in forward
#     be_clip = tc.sum(alphas * (tc.relu(z_norm + thetas) - tc.relu(z_norm)), dim=-1)
#     be_clip = tc.sum(alphas * (tc.relu(z_norm + thetas) - tc.relu(z_norm)), dim=-1)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 106, in forward
#     z = self.latent_step(z, *params)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 254, in forward
#     be_clip = tc.sum(alphas * (tc.relu(z_norm + thetas) - tc.relu(z_norm)), dim=-1)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dendPLRNN/BPTT_TF/bptt/PLRNN_model.py", line 254, in forward
#     be_clip = tc.sum(alphas * (tc.relu(z_norm + thetas) - tc.relu(z_norm)), dim=-1)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# OLD FROM HERE,DO NOT RUN

# %%
# === Setup dendPLRNN on Kaggle ===
# !git clone --depth 1 https://github.com/DurstewitzLab/dendPLRNN.git /kaggle/working/dendPLRNN

# %cd /kaggle/working/dendPLRNN/BPTT_TF

# Install missing dependencies
# !pip install tensorboardX

# Ensure Python can find the modules
import sys
sys.path.append("/kaggle/working/dendPLRNN")
sys.path.append("/kaggle/working/dendPLRNN/BPTT_TF")

print("Setup complete — open and run BPTT_TF/example.ipynb")

# %%
import os

ROOT = "/kaggle/working/dendPLRNN"

def tree(dir_path, prefix=""):
    files = sorted(os.listdir(dir_path))
    for i, f in enumerate(files):
        path = os.path.join(dir_path, f)
        connector = "└── " if i == len(files)-1 else "├── "
        print(prefix + connector + f)
        if os.path.isdir(path):
            extension = "    " if i == len(files)-1 else "│   "
            tree(path, prefix + extension)

print("Project structure:\n")
tree(ROOT)

# %%
# Automatically modify training parameters
# !sed -i 's/maxepoch = [0-9]\+/maxepoch = 200/' ubermain.py
# !sed -i 's/patience = [0-9]\+/patience = 15/' ubermain.py

# %%
# Show only the lines that contain maxepoch and patience
# !grep -nE "maxepoch|patience" ubermain.py

# %%
# !sed -n '1,320p' ubermain.py

# %%
# Search for parameters controlling epochs / training loops
# !grep -nEi "epoch|epochs|iter|max|train|patien" ubermain.py

# Also search calls to train() function
# !grep -nEi "train\(" ubermain.py

# Also search in the underlying training function
# !grep -nEi "epoch|epochs|patien" ../bptt/*.py

# %%
# !grep -nEi "patien" ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG

# Modify epoch count
# !sed -i "s/Argument('n_epochs', \\[[0-9]\+\\])/Argument('n_epochs', [200])/" ubermain.py

# Verify change
# !grep -nEi "n_epochs" ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# !python ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG

# Add the required import if missing
# !sed -i "1s/^/from multitasking import Argument\n/" ubermain.py

# Verify the import was added
# !head -n 20 ubermain.py

# %%
# !python ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG

# Ensure Python can see the BPTT_TF folder
import sys
sys.path.append("/kaggle/working/dendPLRNN/BPTT_TF")

# Modify ubermain.py to import the correct Argument class
# !sed -i "s/from multitasking import Argument/from bptt.multitasking import Argument/" ubermain.py

# If the line does not exist yet, we add it at the top safely
# !sed -i "1s/^/from bptt.multitasking import Argument\n/" ubermain.py

# Show first 15 lines to confirm
# !head -n 15 ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG

# Remove any accidental "from multitasking import *" line
# !sed -i "/from multitasking import/d" ubermain.py

# Remove duplicate Argument imports, keep only one
# !sed -i "0,/from bptt.multitasking import Argument/{/from bptt.multitasking import Argument/{n;d;}}" ubermain.py

# Show first 15 lines to verify
# !head -n 15 ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# !python ubermain.py

# %%
import sys
sys.path.append("/kaggle/working/dendPLRNN")
sys.path.append("/kaggle/working/dendPLRNN/BPTT_TF")

print("PYTHONPATH updated.")

# %%
import bptt
print("bptt module successfully loaded.")

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# !python ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" python ubermain.py

# %%
import sys
sys.path.insert(0, "/kaggle/working/dendPLRNN/BPTT_TF")
sys.path.insert(0, "/kaggle/working/dendPLRNN")
print("Local project PATH added.")

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG

# Remove incorrect old imports
# !sed -i "/from bptt.multitasking import/d" ubermain.py
# !sed -i "/from multitasking import/d" ubermain.py

# Insert the correct import at the top
# !sed -i "1s/^/from multitasking import Argument\n/" ubermain.py

# Show first lines to verify
# !head -n 10 ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" python ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG

# Remove incorrect imports just to avoid duplicates
# !sed -i "/from multitasking import/d" ubermain.py

# Insert the correct import at the top
# !sed -i "1s/^/from multitasking import Argument, run_settings, create_tasks_from_arguments\n/" ubermain.py

# Verify beginning of file
# !head -n 15 ubermain.py

# %%
# %cd /kaggle/working/dendPLRNN/BPTT_TF/Experiments/Table1/ECG
# !PYTHONPATH="/kaggle/working/dendPLRNN/BPTT_TF:/kaggle/working/dendPLRNN" python ubermain.py
